# %%
import numpy as np
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
plt.imshow(np.random.rand(128,128,3))

# %%
a=np.random.rand(100,100)

# %%
a
# Out:
# array([[0.54049599, 0.38679822, 0.34706143, ..., 0.13746212, 0.48536872,
#         0.01572893],
#        [0.06857197, 0.69251184, 0.68720263, ..., 0.17352563, 0.23035078,
#         0.49922707],
#        [0.25489102, 0.08835841, 0.54631123, ..., 0.72616585, 0.01525074,
#         0.28317589],
#        ...,
#        [0.76734273, 0.82849174, 0.5525082 , ..., 0.58401373, 0.40480581,
#         0.61757346],
#        [0.67795179, 0.86023842, 0.81916892, ..., 0.17167416, 0.89571846,
#         0.56651314],
#        [0.00354492, 0.6305267 , 0.64362077, ..., 0.87136578, 0.4650422 ,
#         0.91911696]])

# %%
from flask import Flask
